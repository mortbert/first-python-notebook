# %% [markdown]
# # First Python notebook
# hello world

# %% [markdown]
# import pandas as pd

# %%
pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 5    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 6    ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
# 7    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 8    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 9    ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 10   ocd-contest/9fb6a199-7520-433c-a290-83e016a9d389            1376142
# 11   ocd-contest/e0c5f9f0-63a9-4c15-9a5c-017e20ac15bc            1381642
# ...

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name == 'PROPOSITION 061- STATE PRESCRIPTION DRUG PURCHASES. PRICING STANDARDS. INITIATIVE STATUTE.'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: prop_name, Length: 102, dtype: bool

# %%
props[props.prop_name == 'PROPOSITION 061- STATE PRESCRIPTION DRUG PURCHASES. PRICING STANDARDS. INITIATIVE STATUTE.']
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 60  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 61  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 62  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#     ccdc_prop_id                                          prop_name  \
# 60            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 61            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 62            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 60                442                 1379198
# 61                443                 1376791
# 62                444                 1387641
#
#                                        committee_name committee_position
# 60  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...             OPPOSE
# ...

# %%
prop = props[props.prop_name == 'PROPOSITION 061- STATE PRESCRIPTION DRUG PURCHASES. PRICING STANDARDS. INITIATIVE STATUTE.']

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 60  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 61  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 62  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#     ccdc_prop_id                                          prop_name  \
# 60            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 61            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 62            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 60                442                 1379198
# 61                443                 1376791
# 62                444                 1387641
#
#                                        committee_name committee_position
# 60  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...             OPPOSE
# ...

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 60 to 62
# Data columns (total 8 columns):
# ocd_prop_id               3 non-null object
# calaccess_prop_id         3 non-null int64
# ccdc_prop_id              3 non-null int64
# prop_name                 3 non-null object
# ccdc_committee_id         3 non-null int64
# calaccess_committee_id    3 non-null int64
# committee_name            3 non-null object
# committee_position        3 non-null object
# dtypes: int64(4), object(4)
# memory usage: 216.0+ bytes

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.sort_values("amount")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 654  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 528  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 739  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 456  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 160  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 246  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 364  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 491  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 193  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 765  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 432  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 428  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# ...

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 47   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 6    ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 35   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 613  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 153  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 40   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 15   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 26   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 13   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 49   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 121  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 30   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# ...

# %%
support.sort_values("amount", ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 613  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 153  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 121  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 724  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 743  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#      ccdc_prop_id                                          prop_name  \
# 613            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 153            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 121            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 724            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 743            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 613                443                 1376791
# ...

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    695
# OPPOSE     111
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
oppose.amount.sum()
# Out:
# 108417232.0

# %%
support.amount.sum()
# Out:
# 18897335.25

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 0.14843026731491324

# %%
support.sort_values("amount", ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 613  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 153  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 121  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 724  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 743  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#      ccdc_prop_id                                          prop_name  \
# 613            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 153            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 121            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 724            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 743            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 613                443                 1376791
# ...

# %%
oppose.sort_values("amount", ascending=False).head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 47  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 35  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 6   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 26  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 40  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#     ccdc_prop_id                                          prop_name  \
# 47            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 35            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 6             80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 26            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 40            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 47                442                 1379198
# ...

# %%
merged.sort_values("amount")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 654  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 528  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 739  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 456  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 160  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 246  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 364  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 491  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 193  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 765  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 432  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 428  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# ...

# %%
merged.groupby("committee_name_x")

# %%
merged.groupby("committee_name_x").amount.sum().reset_index()
# Out:
#                                     committee_name_x        amount
# 0  CONSUMER WATCHDOG CAMPAIGN - YES ON 61, MAJOR ...  1.501660e+05
# 1  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...  1.084172e+08
# 2  YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PR...  1.874717e+07

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                     committee_name_x        amount
# 1  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...  1.084172e+08
# 2  YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PR...  1.874717e+07
# 0  CONSUMER WATCHDOG CAMPAIGN - YES ON 61, MAJOR ...  1.501660e+05

# %%
merged.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname contributor_lastname  amount
# 311                   PEG               YORKIN  600.00
# 216                   KIT          BLUMENSTEIN  600.00
# 58              CHRISTINE               CURTIS  600.00
# 31                   BETH            CHAPPELLE  500.00
# 320               RANDALL               MARTIN  500.00
# 261                  MARK              WHISLER  460.87
# 183                JOGEON                   HA  400.00
# 145               GREGORY              LINCOLN  400.00
# 22                 AUDREY      SURMACZ-JOHNSON  250.00
# 192                JOSEPH              WOFFORD  250.00
# 322                    RC              MICHLIN  250.00
# 124                  EVAN               HAZARD  240.00
# 270                  MARY               JEBARA  240.00
# 35                BRADLEY                FLOYD  240.00
# 325                  RITA              COLLINS  220.40
# 143               GREGORY                BROWN  217.20
# ...

# %%
merged.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname contributor_lastname committee_position  amount
# 311                   PEG               YORKIN            SUPPORT  600.00
# 216                   KIT          BLUMENSTEIN            SUPPORT  600.00
# 58              CHRISTINE               CURTIS            SUPPORT  600.00
# 31                   BETH            CHAPPELLE            SUPPORT  500.00
# 320               RANDALL               MARTIN            SUPPORT  500.00
# 261                  MARK              WHISLER            SUPPORT  460.87
# 183                JOGEON                   HA            SUPPORT  400.00
# 145               GREGORY              LINCOLN            SUPPORT  400.00
# 22                 AUDREY      SURMACZ-JOHNSON            SUPPORT  250.00
# 192                JOSEPH              WOFFORD            SUPPORT  250.00
# 322                    RC              MICHLIN            SUPPORT  250.00
# 124                  EVAN               HAZARD            SUPPORT  240.00
# ...

# %%
oppose.sort_values("amount", ascending=False).head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 47  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 35  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 6   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 26  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 40  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#     ccdc_prop_id                                          prop_name  \
# 47            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 35            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 6             80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 26            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 40            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 47                442                 1379198
# ...

# %% [markdown]
# # Sorting by last name to get companies and foundations

# %%
merged.groupby(["contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                            contributor_lastname committee_position      amount
# 6                    AIDS HEALTHCARE FOUNDATION            SUPPORT  18675000.0
# 250                           MERCK & CO., INC.             OPPOSE   9420395.0
# 293                                PFIZER, INC.             OPPOSE   9420395.0
# 182                           JOHNSON & JOHNSON             OPPOSE   9301646.0
# 14                                   AMGEN INC.             OPPOSE   7635768.0
# 0                                   ABBVIE INC.             OPPOSE   6859873.0
# 325                     SANOFI-AVENTIS U.S. LLC             OPPOSE   6720945.0
# 22               ASTRAZENECA PHARMACEUTICALS LP             OPPOSE   6080535.0
# 13                           ALLERGAN USA, INC.             OPPOSE   5079332.0
# 277        NOVARTIS PHARMACEUTICALS CORPORATION             OPPOSE   4728302.0
# 133                             GLAXOSMITHKLINE             OPPOSE   4528527.0
# ...
